# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
from sklearn.utils import shuffle

# %%
class Graph():
    def __init__(self,max_hop=1,strategy="spatial"):
        self.max_hop = max_hop
        self.get_edge()
        self.hop_dis = self.get_hop_distance()
        self.get_adj(strategy)
    def __str__(self):
        return str(self.A)
    
    def get_edge(self):
        self.n_nodes = 20
        edges = [(4,3),(3,5),(5,6),(6,7),(7,8),(3,9),(9,10),
                 (10,11),(11,12),(3,2),(2,1),(1,13),(1,17),
                 (13,14),(14,15),(15,16),(17,18),(18,19),
                 (19,20)] + [(i,i) for i in range(self.n_nodes)]
        self.adjacency = np.zeros((self.n_nodes,self.n_nodes))
        for i, j in edges:
            self.adjacency[i-1,j-1] = 1
            self.adjacency[j-1,i-1] = 1
        self.center=2
    
    def get_adj(self,strategy):
        valid_hop = range(0,self.max_hop+1)
        adjacency = np.zeros((self.n_nodes,self.n_nodes))
        for hop in valid_hop:
            adjacency[self.hop_dis==hop]=1
        normalized_adjacency = self.get_normalized_g(adjacency)
        
        if strategy=='uniform':
            A = np.zeros((1,self.n_nodes,self.n_nodes))
            A[0] = normalized_adjacency
            self.A=A
        elif strategy == 'spatial':
            A = []
            for hop in valid_hop:
                a_root = np.zeros((self.n_nodes,self.n_nodes))
                a_close = np.zeros((self.n_nodes,self.n_nodes))
                a_further = np.zeros((self.n_nodes,self.n_nodes))
                for i in range(self.n_nodes):
                    for j in range(self.n_nodes):
                        if self.hop_dis[j,i] == hop:
                            if self.hop_dis[j, self.center] == self.hop_dis[
                                    i, self.center]:
                                a_root[j, i] = normalized_adjacency[j, i]
                            elif self.hop_dis[j, self.center] > self.hop_dis[i, self.center]:
                                a_close[j, i] = normalized_adjacency[j, i]
                            else:
                                a_further[j, i] = normalized_adjacency[j, i]
                if hop==0:
                    A.append(a_root)
                else:
                    A.append(a_root+a_close)
                    A.append(a_further)
            A = np.stack(A)
            self.A=A
        else:
            raise ValueError("Do no t Exist This Method")
            
            
    def get_normalized_g(self,A):
        degrees = np.sum(self.adjacency,0)
        D = np.zeros((self.n_nodes,self.n_nodes))
        for i in range(self.n_nodes):
            if degrees[i] > 0:
                D[i,i] = degrees[i]**(-1)
        return np.dot(A,D)
        
    def get_hop_distance(self):
        A = self.adjacency
        hop_dis = np.zeros((self.n_nodes,self.n_nodes))+np.inf
        transfer_mat = [np.linalg.matrix_power(A,d) for d in range(self.max_hop+1)]
        arrival_mat = (np.stack(transfer_mat)>0)
        for d in range(self.max_hop,-1,-1):
            hop_dis[arrival_mat[d]] = d
        return hop_dis

# %%
class ConvTemporalGraphical(nn.Module):
    def __init__(self,
                 in_channels,
                 out_channels,
                 kernel_size,
                 t_kernel_size=1,
                 t_stride=1,
                 t_padding=0,
                 t_dilation=1,
                 bias=True):
        super().__init__()

        self.kernel_size = kernel_size
        self.conv = nn.Conv2d(
            in_channels,
            out_channels * kernel_size,
            kernel_size=(t_kernel_size, 1),
            padding=(t_padding, 0),
            stride=(t_stride, 1),
            dilation=(t_dilation, 1),
            bias=bias)

    def forward(self, x, A):
        assert A.size(0) == self.kernel_size
        x = self.conv(x)
        n, kc, t, v = x.size()
        x = x.view(n, self.kernel_size, kc//self.kernel_size, t, v)
        x = torch.einsum('nkctv,kvw->nctw', (x, A))
        return x.contiguous(), A

# %%
class Model(nn.Module):
    """Spatial temporal graph convolutional networks.
    Args:
        in_channels (int): Number of channels in the input data
        num_class (int): Number of classes for the classification task
        graph_args (dict): The arguments for building the graph
        edge_importance_weighting (bool): If ``True``, adds a learnable
            importance weighting to the edges of the graph
        **kwargs (optional): Other parameters for graph convolution units
    Shape:
        - Input: :math:`(N, in_channels, T_{in}, V_{in}, M_{in})`
        - Output: :math:`(N, num_class)` where
            :math:`N` is a batch size,
            :math:`T_{in}` is a length of input sequence,
            :math:`V_{in}` is the number of graph nodes,
            :math:`M_{in}` is the number of instance in a frame.
    """

    def __init__(self, in_channels, num_class,
                 edge_importance_weighting=None, **kwargs):
        super().__init__()

        # load graph
        self.graph = Graph()
        A = torch.tensor(self.graph.A, dtype=torch.float32, requires_grad=False)
        self.register_buffer('A', A)

        # build networks
        spatial_kernel_size = A.size(0)
        temporal_kernel_size = 3
        kernel_size = (temporal_kernel_size, spatial_kernel_size)
        self.data_bn = nn.BatchNorm1d(in_channels * A.size(1))
        kwargs0 = {k: v for k, v in kwargs.items() if k != 'dropout'}
        self.st_gcn_networks = nn.ModuleList((
            st_gcn(in_channels, 32, kernel_size, 1, residual=False, **kwargs0),
            st_gcn(32, 32, kernel_size, 1, **kwargs),
            st_gcn(32, 32, kernel_size, 1, **kwargs),
            st_gcn(32, 32, kernel_size, 1, **kwargs),
            st_gcn(32, 64, kernel_size, 2, **kwargs),
            st_gcn(64, 64, kernel_size, 1, **kwargs),
            st_gcn(64, 64, kernel_size, 1, **kwargs),
            st_gcn(64, 128, kernel_size, 2, **kwargs),
            st_gcn(128, 128, kernel_size, 1, **kwargs),
            st_gcn(128, 128, kernel_size, 1, **kwargs),
        ))

        # initialize parameters for edge importance weighting
        if edge_importance_weighting:
            self.edge_importance = nn.ParameterList([
                nn.Parameter(torch.ones(self.A.size()))
                for i in self.st_gcn_networks
            ])
        else:
            self.edge_importance = [1] * len(self.st_gcn_networks)

        # fcn for prediction
        self.fcn = nn.Conv2d(128, num_class, kernel_size=1)

    def forward(self, x):

        # data normalization
        N, C, V, T= x.size()
        x = x.permute(0, 2, 1, 3).contiguous()
        x = x.view(N, V * C, T)
        x = self.data_bn(x)
        x = x.view(N, V, C, T)
        x = x.permute(0, 2, 3, 1).contiguous()
        x = x.view(N, C, T, V)        
        # forwad
        for gcn, importance in zip(self.st_gcn_networks, self.edge_importance):
            x, _ = gcn(x, self.A * importance)

        # global pooling
        
        x = F.avg_pool2d(x, x.size()[2:])

        # prediction
        x = self.fcn(x)
        x = x.view(x.size(0), -1)

        return x

    def extract_feature(self, x):

        # data normalization
        N, C, V, T= x.size()
        x = x.permute(0, 2, 1, 3).contiguous()
        x = x.view(N, V * C, T)
        x = self.data_bn(x)
        x = x.view(N, V, C, T)
        x = x.permute(0, 2, 3, 1).contiguous()
        x = x.view(N, C, T, V)  

        # forwad
        for gcn, importance in zip(self.st_gcn_networks, self.edge_importance):
            x, _ = gcn(x, self.A * importance)

        _, c, t, v = x.size()
        feature = x.view(N, c, t, v).permute(0, 1, 2, 3)

        # prediction
        x = self.fcn(x)
        output = x.view(N, -1, t, v).permute(0, 1, 2, 3)

        return output, feature

class st_gcn(nn.Module):
    """Applies a spatial temporal graph convolution over an input graph sequence.
    Args:
        in_channels (int): Number of channels in the input sequence data
        out_channels (int): Number of channels produced by the convolution
        kernel_size (tuple): Size of the temporal convolving kernel and graph convolving kernel
        stride (int, optional): Stride of the temporal convolution. Default: 1
        dropout (int, optional): Dropout rate of the final output. Default: 0
        residual (bool, optional): If ``True``, applies a residual mechanism. Default: ``True``
    Shape:
        - Input[0]: Input graph sequence in :math:`(N, in_channels, T_{in}, V)` format
        - Input[1]: Input graph adjacency matrix in :math:`(K, V, V)` format
        - Output[0]: Outpu graph sequence in :math:`(N, out_channels, T_{out}, V)` format
        - Output[1]: Graph adjacency matrix for output data in :math:`(K, V, V)` format
        where
            :math:`N` is a batch size,
            :math:`K` is the spatial kernel size, as :math:`K == kernel_size[1]`,
            :math:`T_{in}/T_{out}` is a length of input/output sequence,
            :math:`V` is the number of graph nodes.
    """

    def __init__(self,
                 in_channels,
                 out_channels,
                 kernel_size,
                 stride=1,
                 dropout=0,
                 residual=True):
        super().__init__()

        assert len(kernel_size) == 2
        assert kernel_size[0] % 2 == 1
        padding = ((kernel_size[0] - 1) // 2, 0)

        self.gcn = ConvTemporalGraphical(in_channels, out_channels,
                                         kernel_size[1])

        self.tcn = nn.Sequential(
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(
                out_channels,
                out_channels,
                (kernel_size[0], 1),
                (stride, 1),
                padding,
            ),
            nn.BatchNorm2d(out_channels),
            nn.Dropout(dropout, inplace=True),
        )

        if not residual:
            self.residual = lambda x: 0

        elif (in_channels == out_channels) and (stride == 1):
            self.residual = lambda x: x

        else:
            self.residual = nn.Sequential(
                nn.Conv2d(
                    in_channels,
                    out_channels,
                    kernel_size=1,
                    stride=(stride, 1)),
                nn.BatchNorm2d(out_channels),
            )

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x, A):

        res = self.residual(x)
        x, A = self.gcn(x, A)
        x = self.tcn(x) + res
        
        return self.relu(x), A

# %%
class GCNDataset(Dataset):
    def __init__(self,filename,hasLabel=True):
        self.df = pd.read_csv(filename,header=None)
        if hasLabel:
            self.df['freq']=1./self.df.groupby(961)[961].transform('count')
            self.df = self.df.sample(frac=1,weights=self.df.freq).reset_index(drop=True)
        self.length = len(self.df)
        if hasLabel:
            self.X = torch.tensor(self.df.iloc[:,1:-2].values.astype('float32'))
            # N, C, V, T
            self.X = self.X.reshape((self.length ,16, 20, 3)).permute(0,3,2,1).contiguous()
            labels = self.df.iloc[:,-2].values.astype('int32')-1
            self.Y = np.zeros((labels.size, labels.max()+1))
            self.Y[np.arange(labels.size),labels] = 1
        else:
            self.X = torch.tensor(self.df.iloc[:,1:].values.astype('float32'))
            self.X = self.X.reshape((self.length ,16, 20, 3)).permute(0,3,2,1).contiguous()
            self.Y = np.zeros((self.length,49))
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self,index):
        x = self.X[index]
        y = self.Y[index]
        return x, y

# %%
train_set = GCNDataset(filename="drive/MyDrive/SML/training_set.csv")
val_set = GCNDataset(filename="drive/MyDrive/SML/val_set.csv")
test_set = GCNDataset(filename="drive/MyDrive/SML/test.csv",hasLabel=False)
train_loader = DataLoader(train_set,batch_size=64)
val_loader = DataLoader(val_set,batch_size=64)
test_loader = DataLoader(test_set,batch_size=64)
net = Model(3,49)
#net.load_state_dict(torch.load("stgcn-best.pkl"))
gpu = 0 #gpu ID
net.cuda(gpu)
print()

# %%
import torch.nn as nn
import torch.optim as optim

criterion = nn.BCEWithLogitsLoss()
opti = optim.Adam(net.parameters(), lr = 2e-5)
#opti.load_state_dict(torch.load('stgcn_best_optim.pkl'))
def accuracy(logit,target):
    a=(torch.argmax(logit,dim=1)==torch.argmax(target,dim=1)).sum()
    return a

def evaluate(model, criterion, dataloader, gpu):
    model.eval()
    acc = 0
    count = 0
    with torch.no_grad():
        for i,(x,y) in enumerate(dataloader):
            x,y = x.cuda(gpu), y.cuda(gpu)
            logits = model(x)
            acc+= accuracy(logits, y)
            count += 64

    return acc / count

def train():
    best_acc=0.35
    best_epoch = 0
    for epoch in range(200):
        print("epoch:",epoch)
        total = 0
        correct = 0
        for i, (x,y) in enumerate(train_loader):
            opti.zero_grad()
            x,y=x.cuda(gpu),y.cuda(gpu)
            opti.zero_grad()
            logit = net(x)
            loss = criterion(logit,y)
            loss.backward()
            opti.step()
            correct+=accuracy(logit,y)
            total+=64
        print("train acc:",correct/total)

        dev_acc = evaluate(net, criterion, val_loader, gpu)
        if dev_acc>best_acc:
            best_acc=dev_acc
            torch.save(net.state_dict(), 'stgcn-best.pkl')
            torch.save(opti.state_dict(), "stgcn_best_optim.pkl")
        print("dev_acc:",dev_acc)
train()
# Out:
# epoch: 0
# train acc: tensor(0.0070, device='cuda:0')
# dev_acc: tensor(0.0094, device='cuda:0')
# epoch: 1
# train acc: tensor(0.1225, device='cuda:0')
# dev_acc: tensor(0.1646, device='cuda:0')
# epoch: 2
# train acc: tensor(0.1745, device='cuda:0')
# dev_acc: tensor(0.1589, device='cuda:0')
# epoch: 3
# train acc: tensor(0.1886, device='cuda:0')
# dev_acc: tensor(0.1630, device='cuda:0')
# epoch: 4
# train acc: tensor(0.2033, device='cuda:0')
# dev_acc: tensor(0.1781, device='cuda:0')
# epoch: 5
# train acc: tensor(0.2154, device='cuda:0')
# dev_acc: tensor(0.1880, device='cuda:0')
# epoch: 6
# train acc: tensor(0.2230, device='cuda:0')
# dev_acc: tensor(0.1948, device='cuda:0')
# epoch: 7
# train acc: tensor(0.2311, device='cuda:0')
# dev_acc: tensor(0.1990, device='cuda:0')
# epoch: 8
# train acc: tensor(0.2395, device='cuda:0')
# dev_acc: tensor(0.2042, device='cuda:0')
# epoch: 9
# train acc: tensor(0.2466, device='cuda:0')
# dev_acc: tensor(0.2063, device='cuda:0')
# epoch: 10
# train acc: tensor(0.2516, device='cuda:0')
# dev_acc: tensor(0.2083, device='cuda:0')
# epoch: 11
# train acc: tensor(0.2566, device='cuda:0')
# dev_acc: tensor(0.2109, device='cuda:0')
# epoch: 12
# train acc: tensor(0.2611, device='cuda:0')
# dev_acc: tensor(0.2177, device='cuda:0')
# epoch: 13
# train acc: tensor(0.2673, device='cuda:0')
# dev_acc: tensor(0.2286, device='cuda:0')
# epoch: 14
# train acc: tensor(0.2732, device='cuda:0')
# dev_acc: tensor(0.2365, device='cuda:0')
# epoch: 15
# train acc: tensor(0.2791, device='cuda:0')
# dev_acc: tensor(0.2385, device='cuda:0')
# epoch: 16
# train acc: tensor(0.2847, device='cuda:0')
# dev_acc: tensor(0.2432, device='cuda:0')
# epoch: 17
# train acc: tensor(0.2891, device='cuda:0')
# dev_acc: tensor(0.2464, device='cuda:0')
# epoch: 18
# train acc: tensor(0.2949, device='cuda:0')
# dev_acc: tensor(0.2516, device='cuda:0')
# epoch: 19
# train acc: tensor(0.2994, device='cuda:0')
# dev_acc: tensor(0.2484, device='cuda:0')
# epoch: 20
# train acc: tensor(0.3035, device='cuda:0')
# dev_acc: tensor(0.2542, device='cuda:0')
# epoch: 21
# train acc: tensor(0.3092, device='cuda:0')
# dev_acc: tensor(0.2604, device='cuda:0')
# epoch: 22
# train acc: tensor(0.3136, device='cuda:0')
# dev_acc: tensor(0.2688, device='cuda:0')
# epoch: 23
# train acc: tensor(0.3165, device='cuda:0')
# dev_acc: tensor(0.2714, device='cuda:0')
# epoch: 24
# train acc: tensor(0.3202, device='cuda:0')
# dev_acc: tensor(0.2729, device='cuda:0')
# epoch: 25
# train acc: tensor(0.3273, device='cuda:0')
# dev_acc: tensor(0.2781, device='cuda:0')
# epoch: 26
# train acc: tensor(0.3326, device='cuda:0')
# dev_acc: tensor(0.2828, device='cuda:0')
# epoch: 27
# train acc: tensor(0.3385, device='cuda:0')
# dev_acc: tensor(0.2833, device='cuda:0')
# epoch: 28
# train acc: tensor(0.3441, device='cuda:0')
# dev_acc: tensor(0.2891, device='cuda:0')
# epoch: 29
# train acc: tensor(0.3502, device='cuda:0')
# dev_acc: tensor(0.2906, device='cuda:0')
# epoch: 30
# train acc: tensor(0.3549, device='cuda:0')
# dev_acc: tensor(0.2911, device='cuda:0')
# epoch: 31
# train acc: tensor(0.3598, device='cuda:0')
# dev_acc: tensor(0.2943, device='cuda:0')
# epoch: 32
# train acc: tensor(0.3641, device='cuda:0')
# dev_acc: tensor(0.2974, device='cuda:0')
# epoch: 33
# train acc: tensor(0.3686, device='cuda:0')
# dev_acc: tensor(0.2995, device='cuda:0')
# epoch: 34
# train acc: tensor(0.3725, device='cuda:0')
# dev_acc: tensor(0.3031, device='cuda:0')
# epoch: 35
# train acc: tensor(0.3754, device='cuda:0')
# dev_acc: tensor(0.3063, device='cuda:0')
# epoch: 36
# train acc: tensor(0.3784, device='cuda:0')
# dev_acc: tensor(0.3104, device='cuda:0')
# epoch: 37
# train acc: tensor(0.3816, device='cuda:0')
# dev_acc: tensor(0.3104, device='cuda:0')
# epoch: 38
# train acc: tensor(0.3841, device='cuda:0')
# dev_acc: tensor(0.3120, device='cuda:0')
# epoch: 39
# train acc: tensor(0.3886, device='cuda:0')
# dev_acc: tensor(0.3141, device='cuda:0')
# epoch: 40
# train acc: tensor(0.3925, device='cuda:0')
# dev_acc: tensor(0.3161, device='cuda:0')
# epoch: 41
# train acc: tensor(0.3962, device='cuda:0')
# dev_acc: tensor(0.3161, device='cuda:0')
# epoch: 42
# train acc: tensor(0.4021, device='cuda:0')
# dev_acc: tensor(0.3151, device='cuda:0')
# epoch: 43
# train acc: tensor(0.4048, device='cuda:0')
# dev_acc: tensor(0.3161, device='cuda:0')
# epoch: 44
# train acc: tensor(0.4088, device='cuda:0')
# dev_acc: tensor(0.3193, device='cuda:0')
# epoch: 45
# train acc: tensor(0.4110, device='cuda:0')
# dev_acc: tensor(0.3229, device='cuda:0')
# epoch: 46
# train acc: tensor(0.4135, device='cuda:0')
# dev_acc: tensor(0.3245, device='cuda:0')
# epoch: 47
# train acc: tensor(0.4158, device='cuda:0')
# dev_acc: tensor(0.3260, device='cuda:0')
# epoch: 48
# train acc: tensor(0.4198, device='cuda:0')
# dev_acc: tensor(0.3271, device='cuda:0')
# epoch: 49
# train acc: tensor(0.4231, device='cuda:0')
# dev_acc: tensor(0.3286, device='cuda:0')
# epoch: 50
# train acc: tensor(0.4258, device='cuda:0')
# dev_acc: tensor(0.3318, device='cuda:0')
# epoch: 51
# train acc: tensor(0.4296, device='cuda:0')
# dev_acc: tensor(0.3354, device='cuda:0')
# epoch: 52
# train acc: tensor(0.4313, device='cuda:0')
# dev_acc: tensor(0.3365, device='cuda:0')
# epoch: 53
# train acc: tensor(0.4347, device='cuda:0')
# dev_acc: tensor(0.3385, device='cuda:0')
# epoch: 54
# train acc: tensor(0.4367, device='cuda:0')
# dev_acc: tensor(0.3401, device='cuda:0')
# epoch: 55
# train acc: tensor(0.4387, device='cuda:0')
# dev_acc: tensor(0.3438, device='cuda:0')
# epoch: 56
# train acc: tensor(0.4407, device='cuda:0')
# dev_acc: tensor(0.3443, device='cuda:0')
# epoch: 57
# train acc: tensor(0.4436, device='cuda:0')
# dev_acc: tensor(0.3453, device='cuda:0')
# epoch: 58
# train acc: tensor(0.4445, device='cuda:0')
# dev_acc: tensor(0.3448, device='cuda:0')
# epoch: 59
# train acc: tensor(0.4469, device='cuda:0')
# dev_acc: tensor(0.3443, device='cuda:0')
# epoch: 60
# train acc: tensor(0.4488, device='cuda:0')
# dev_acc: tensor(0.3453, device='cuda:0')
# epoch: 61
# train acc: tensor(0.4513, device='cuda:0')
# dev_acc: tensor(0.3479, device='cuda:0')
# epoch: 62
# train acc: tensor(0.4544, device='cuda:0')
# dev_acc: tensor(0.3495, device='cuda:0')
# epoch: 63
# train acc: tensor(0.4570, device='cuda:0')
# dev_acc: tensor(0.3510, device='cuda:0')
# epoch: 64
# train acc: tensor(0.4590, device='cuda:0')
# dev_acc: tensor(0.3521, device='cuda:0')
# epoch: 65
# train acc: tensor(0.4628, device='cuda:0')
# dev_acc: tensor(0.3526, device='cuda:0')
# epoch: 66
# train acc: tensor(0.4656, device='cuda:0')
# dev_acc: tensor(0.3531, device='cuda:0')
# epoch: 67
# train acc: tensor(0.4690, device='cuda:0')
# dev_acc: tensor(0.3536, device='cuda:0')
# epoch: 68
# train acc: tensor(0.4710, device='cuda:0')
# dev_acc: tensor(0.3526, device='cuda:0')
# epoch: 69
# train acc: tensor(0.4729, device='cuda:0')
# dev_acc: tensor(0.3526, device='cuda:0')
# epoch: 70
# train acc: tensor(0.4743, device='cuda:0')
# dev_acc: tensor(0.3547, device='cuda:0')
# epoch: 71
# train acc: tensor(0.4775, device='cuda:0')
# dev_acc: tensor(0.3547, device='cuda:0')
# epoch: 72
# train acc: tensor(0.4795, device='cuda:0')
# dev_acc: tensor(0.3563, device='cuda:0')
# epoch: 73
# train acc: tensor(0.4813, device='cuda:0')
# dev_acc: tensor(0.3583, device='cuda:0')
# epoch: 74
# train acc: tensor(0.4829, device='cuda:0')
# dev_acc: tensor(0.3589, device='cuda:0')
# epoch: 75
# train acc: tensor(0.4864, device='cuda:0')
# dev_acc: tensor(0.3578, device='cuda:0')
# epoch: 76
# train acc: tensor(0.4886, device='cuda:0')
# dev_acc: tensor(0.3583, device='cuda:0')
# epoch: 77
# train acc: tensor(0.4910, device='cuda:0')
# dev_acc: tensor(0.3604, device='cuda:0')
# epoch: 78
# train acc: tensor(0.4934, device='cuda:0')
# dev_acc: tensor(0.3620, device='cuda:0')
# epoch: 79
# train acc: tensor(0.4963, device='cuda:0')
# dev_acc: tensor(0.3625, device='cuda:0')
# epoch: 80
# train acc: tensor(0.4991, device='cuda:0')
# dev_acc: tensor(0.3656, device='cuda:0')
# epoch: 81
# train acc: tensor(0.5016, device='cuda:0')
# dev_acc: tensor(0.3667, device='cuda:0')
# epoch: 82
# train acc: tensor(0.5041, device='cuda:0')
# dev_acc: tensor(0.3667, device='cuda:0')
# epoch: 83
# train acc: tensor(0.5058, device='cuda:0')
# dev_acc: tensor(0.3672, device='cuda:0')
# epoch: 84
# train acc: tensor(0.5086, device='cuda:0')
# dev_acc: tensor(0.3688, device='cuda:0')
# epoch: 85
# train acc: tensor(0.5099, device='cuda:0')
# dev_acc: tensor(0.3714, device='cuda:0')
# epoch: 86
# train acc: tensor(0.5124, device='cuda:0')
# dev_acc: tensor(0.3734, device='cuda:0')
# epoch: 87
# train acc: tensor(0.5151, device='cuda:0')
# dev_acc: tensor(0.3740, device='cuda:0')
# epoch: 88
# train acc: tensor(0.5175, device='cuda:0')
# dev_acc: tensor(0.3755, device='cuda:0')
# epoch: 89
# train acc: tensor(0.5200, device='cuda:0')
# dev_acc: tensor(0.3766, device='cuda:0')
# epoch: 90
# train acc: tensor(0.5225, device='cuda:0')
# dev_acc: tensor(0.3776, device='cuda:0')
# epoch: 91
# train acc: tensor(0.5234, device='cuda:0')
# dev_acc: tensor(0.3781, device='cuda:0')
# epoch: 92
# train acc: tensor(0.5245, device='cuda:0')
# dev_acc: tensor(0.3792, device='cuda:0')
# epoch: 93
# train acc: tensor(0.5273, device='cuda:0')
# dev_acc: tensor(0.3797, device='cuda:0')
# epoch: 94
# train acc: tensor(0.5294, device='cuda:0')
# dev_acc: tensor(0.3797, device='cuda:0')
# epoch: 95
# train acc: tensor(0.5310, device='cuda:0')
# dev_acc: tensor(0.3797, device='cuda:0')
# epoch: 96
# train acc: tensor(0.5327, device='cuda:0')
# dev_acc: tensor(0.3802, device='cuda:0')
# epoch: 97
# train acc: tensor(0.5342, device='cuda:0')
# dev_acc: tensor(0.3797, device='cuda:0')
# epoch: 98
# train acc: tensor(0.5359, device='cuda:0')
# dev_acc: tensor(0.3797, device='cuda:0')
# epoch: 99
# train acc: tensor(0.5383, device='cuda:0')
# dev_acc: tensor(0.3807, device='cuda:0')
# epoch: 100
# train acc: tensor(0.5393, device='cuda:0')
# dev_acc: tensor(0.3813, device='cuda:0')
# epoch: 101
# train acc: tensor(0.5413, device='cuda:0')
# dev_acc: tensor(0.3823, device='cuda:0')
# epoch: 102
# train acc: tensor(0.5436, device='cuda:0')
# dev_acc: tensor(0.3823, device='cuda:0')
# epoch: 103
# train acc: tensor(0.5456, device='cuda:0')
# dev_acc: tensor(0.3844, device='cuda:0')
# epoch: 104
# train acc: tensor(0.5473, device='cuda:0')
# dev_acc: tensor(0.3844, device='cuda:0')
# epoch: 105
# train acc: tensor(0.5490, device='cuda:0')
# dev_acc: tensor(0.3854, device='cuda:0')
# epoch: 106
# train acc: tensor(0.5507, device='cuda:0')
# dev_acc: tensor(0.3854, device='cuda:0')
# epoch: 107
# train acc: tensor(0.5531, device='cuda:0')
# dev_acc: tensor(0.3854, device='cuda:0')
# epoch: 108
# train acc: tensor(0.5553, device='cuda:0')
# dev_acc: tensor(0.3885, device='cuda:0')
# epoch: 109
# train acc: tensor(0.5580, device='cuda:0')
# dev_acc: tensor(0.3896, device='cuda:0')
# epoch: 110
# train acc: tensor(0.5597, device='cuda:0')
# dev_acc: tensor(0.3901, device='cuda:0')
# epoch: 111
# train acc: tensor(0.5624, device='cuda:0')
# dev_acc: tensor(0.3922, device='cuda:0')
# epoch: 112
# train acc: tensor(0.5640, device='cuda:0')
# dev_acc: tensor(0.3917, device='cuda:0')
# epoch: 113
# train acc: tensor(0.5653, device='cuda:0')
# dev_acc: tensor(0.3917, device='cuda:0')
# epoch: 114
# train acc: tensor(0.5665, device='cuda:0')
# dev_acc: tensor(0.3917, device='cuda:0')
# epoch: 115
# train acc: tensor(0.5686, device='cuda:0')
# dev_acc: tensor(0.3922, device='cuda:0')
# epoch: 116
# train acc: tensor(0.5703, device='cuda:0')
# dev_acc: tensor(0.3922, device='cuda:0')
# epoch: 117
# train acc: tensor(0.5719, device='cuda:0')
# dev_acc: tensor(0.3932, device='cuda:0')
# epoch: 118
# train acc: tensor(0.5732, device='cuda:0')
# dev_acc: tensor(0.3948, device='cuda:0')
# epoch: 119
# train acc: tensor(0.5759, device='cuda:0')
# dev_acc: tensor(0.3964, device='cuda:0')
# epoch: 120
# train acc: tensor(0.5779, device='cuda:0')
# dev_acc: tensor(0.3964, device='cuda:0')
# epoch: 121
# train acc: tensor(0.5788, device='cuda:0')
# dev_acc: tensor(0.3958, device='cuda:0')
# epoch: 122
# train acc: tensor(0.5813, device='cuda:0')
# dev_acc: tensor(0.3964, device='cuda:0')
# epoch: 123
# train acc: tensor(0.5828, device='cuda:0')
# dev_acc: tensor(0.3969, device='cuda:0')
# epoch: 124
# train acc: tensor(0.5846, device='cuda:0')
# dev_acc: tensor(0.3984, device='cuda:0')
# epoch: 125
# train acc: tensor(0.5871, device='cuda:0')
# dev_acc: tensor(0.3984, device='cuda:0')
# epoch: 126
# train acc: tensor(0.5898, device='cuda:0')
# dev_acc: tensor(0.3990, device='cuda:0')
# epoch: 127
# train acc: tensor(0.5912, device='cuda:0')
# dev_acc: tensor(0.3995, device='cuda:0')
# epoch: 128
# train acc: tensor(0.5924, device='cuda:0')
# dev_acc: tensor(0.4005, device='cuda:0')
# epoch: 129
# train acc: tensor(0.5951, device='cuda:0')
# dev_acc: tensor(0.4005, device='cuda:0')
# epoch: 130
# train acc: tensor(0.5975, device='cuda:0')
# dev_acc: tensor(0.3984, device='cuda:0')
# epoch: 131
# train acc: tensor(0.5989, device='cuda:0')
# dev_acc: tensor(0.4000, device='cuda:0')
# epoch: 132
# train acc: tensor(0.5998, device='cuda:0')
# dev_acc: tensor(0.4016, device='cuda:0')
# epoch: 133
# train acc: tensor(0.6026, device='cuda:0')
# dev_acc: tensor(0.4010, device='cuda:0')
# epoch: 134
# train acc: tensor(0.6037, device='cuda:0')
# dev_acc: tensor(0.4026, device='cuda:0')
# epoch: 135
# train acc: tensor(0.6063, device='cuda:0')
# dev_acc: tensor(0.4026, device='cuda:0')
# epoch: 136
# train acc: tensor(0.6081, device='cuda:0')
# dev_acc: tensor(0.4026, device='cuda:0')
# epoch: 137
# train acc: tensor(0.6106, device='cuda:0')
# dev_acc: tensor(0.4031, device='cuda:0')
# epoch: 138
# train acc: tensor(0.6124, device='cuda:0')
# dev_acc: tensor(0.4031, device='cuda:0')
# epoch: 139
# train acc: tensor(0.6135, device='cuda:0')
# dev_acc: tensor(0.4010, device='cuda:0')
# epoch: 140
# train acc: tensor(0.6161, device='cuda:0')
# dev_acc: tensor(0.4016, device='cuda:0')
# epoch: 141
# train acc: tensor(0.6173, device='cuda:0')
# dev_acc: tensor(0.4021, device='cuda:0')
# epoch: 142
# train acc: tensor(0.6181, device='cuda:0')
# dev_acc: tensor(0.4016, device='cuda:0')
# epoch: 143
# train acc: tensor(0.6196, device='cuda:0')
# dev_acc: tensor(0.4010, device='cuda:0')
# epoch: 144
# train acc: tensor(0.6210, device='cuda:0')
# dev_acc: tensor(0.4010, device='cuda:0')
# epoch: 145
# train acc: tensor(0.6230, device='cuda:0')
# dev_acc: tensor(0.4016, device='cuda:0')
# epoch: 146
# train acc: tensor(0.6250, device='cuda:0')
# dev_acc: tensor(0.4010, device='cuda:0')
# epoch: 147
# train acc: tensor(0.6266, device='cuda:0')
# dev_acc: tensor(0.4021, device='cuda:0')
# epoch: 148
# train acc: tensor(0.6282, device='cuda:0')
# dev_acc: tensor(0.4021, device='cuda:0')
# epoch: 149
# train acc: tensor(0.6304, device='cuda:0')
# dev_acc: tensor(0.4036, device='cuda:0')
# epoch: 150
# train acc: tensor(0.6318, device='cuda:0')
# dev_acc: tensor(0.4042, device='cuda:0')
# epoch: 151
# train acc: tensor(0.6332, device='cuda:0')
# dev_acc: tensor(0.4047, device='cuda:0')
# epoch: 152
# train acc: tensor(0.6348, device='cuda:0')
# dev_acc: tensor(0.4042, device='cuda:0')
# epoch: 153
# train acc: tensor(0.6378, device='cuda:0')
# dev_acc: tensor(0.4052, device='cuda:0')
# epoch: 154
# train acc: tensor(0.6397, device='cuda:0')
# dev_acc: tensor(0.4031, device='cuda:0')
# epoch: 155
# train acc: tensor(0.6412, device='cuda:0')
# dev_acc: tensor(0.4052, device='cuda:0')
# epoch: 156
# train acc: tensor(0.6425, device='cuda:0')
# dev_acc: tensor(0.4057, device='cuda:0')
# epoch: 157
# train acc: tensor(0.6434, device='cuda:0')
# dev_acc: tensor(0.4078, device='cuda:0')
# epoch: 158
# train acc: tensor(0.6446, device='cuda:0')
# dev_acc: tensor(0.4078, device='cuda:0')
# epoch: 159
# train acc: tensor(0.6457, device='cuda:0')
# dev_acc: tensor(0.4094, device='cuda:0')
# epoch: 160
# train acc: tensor(0.6474, device='cuda:0')
# dev_acc: tensor(0.4104, device='cuda:0')
# epoch: 161
# train acc: tensor(0.6487, device='cuda:0')
# dev_acc: tensor(0.4115, device='cuda:0')
# epoch: 162
# train acc: tensor(0.6504, device='cuda:0')
# dev_acc: tensor(0.4109, device='cuda:0')
# epoch: 163
# train acc: tensor(0.6529, device='cuda:0')
# dev_acc: tensor(0.4115, device='cuda:0')
# epoch: 164
# train acc: tensor(0.6540, device='cuda:0')
# dev_acc: tensor(0.4120, device='cuda:0')
# epoch: 165
# train acc: tensor(0.6553, device='cuda:0')
# dev_acc: tensor(0.4125, device='cuda:0')
# epoch: 166
# train acc: tensor(0.6577, device='cuda:0')
# dev_acc: tensor(0.4135, device='cuda:0')
# epoch: 167
# train acc: tensor(0.6596, device='cuda:0')
# dev_acc: tensor(0.4141, device='cuda:0')
# epoch: 168
# train acc: tensor(0.6613, device='cuda:0')
# dev_acc: tensor(0.4141, device='cuda:0')
# epoch: 169
# train acc: tensor(0.6621, device='cuda:0')
# dev_acc: tensor(0.4156, device='cuda:0')
# epoch: 170
# train acc: tensor(0.6626, device='cuda:0')
# dev_acc: tensor(0.4167, device='cuda:0')
# epoch: 171
# train acc: tensor(0.6643, device='cuda:0')
# dev_acc: tensor(0.4177, device='cuda:0')
# epoch: 172
# train acc: tensor(0.6655, device='cuda:0')
# dev_acc: tensor(0.4177, device='cuda:0')
# epoch: 173
# train acc: tensor(0.6668, device='cuda:0')
# dev_acc: tensor(0.4182, device='cuda:0')
# epoch: 174
# train acc: tensor(0.6690, device='cuda:0')
# dev_acc: tensor(0.4198, device='cuda:0')
# epoch: 175
# train acc: tensor(0.6712, device='cuda:0')
# dev_acc: tensor(0.4198, device='cuda:0')
# epoch: 176
# train acc: tensor(0.6727, device='cuda:0')
# dev_acc: tensor(0.4193, device='cuda:0')
# epoch: 177
# train acc: tensor(0.6732, device='cuda:0')
# dev_acc: tensor(0.4198, device='cuda:0')
# epoch: 178
# train acc: tensor(0.6745, device='cuda:0')
# dev_acc: tensor(0.4214, device='cuda:0')
# epoch: 179
# train acc: tensor(0.6748, device='cuda:0')
# dev_acc: tensor(0.4214, device='cuda:0')
# epoch: 180
# train acc: tensor(0.6770, device='cuda:0')
# dev_acc: tensor(0.4208, device='cuda:0')
# epoch: 181
# train acc: tensor(0.6781, device='cuda:0')
# dev_acc: tensor(0.4203, device='cuda:0')
# epoch: 182
# train acc: tensor(0.6797, device='cuda:0')
# dev_acc: tensor(0.4198, device='cuda:0')
# epoch: 183
# train acc: tensor(0.6810, device='cuda:0')
# dev_acc: tensor(0.4193, device='cuda:0')
# epoch: 184
# train acc: tensor(0.6831, device='cuda:0')
# dev_acc: tensor(0.4203, device='cuda:0')
# epoch: 185
# train acc: tensor(0.6843, device='cuda:0')
# dev_acc: tensor(0.4224, device='cuda:0')
# epoch: 186
# train acc: tensor(0.6860, device='cuda:0')
# dev_acc: tensor(0.4229, device='cuda:0')
# epoch: 187
# train acc: tensor(0.6868, device='cuda:0')
# dev_acc: tensor(0.4245, device='cuda:0')
# epoch: 188
# train acc: tensor(0.6890, device='cuda:0')
# dev_acc: tensor(0.4255, device='cuda:0')
# epoch: 189
# train acc: tensor(0.6908, device='cuda:0')
# dev_acc: tensor(0.4245, device='cuda:0')
# epoch: 190
# train acc: tensor(0.6919, device='cuda:0')
# dev_acc: tensor(0.4250, device='cuda:0')
# epoch: 191
# train acc: tensor(0.6935, device='cuda:0')
# dev_acc: tensor(0.4245, device='cuda:0')
# epoch: 192
# train acc: tensor(0.6947, device='cuda:0')
# dev_acc: tensor(0.4245, device='cuda:0')
# epoch: 193
# train acc: tensor(0.6968, device='cuda:0')
# dev_acc: tensor(0.4250, device='cuda:0')
# epoch: 194
# train acc: tensor(0.6989, device='cuda:0')
# dev_acc: tensor(0.4255, device='cuda:0')
# epoch: 195
# train acc: tensor(0.7006, device='cuda:0')
# dev_acc: tensor(0.4250, device='cuda:0')
# epoch: 196
# train acc: tensor(0.7027, device='cuda:0')
# dev_acc: tensor(0.4240, device='cuda:0')
# epoch: 197
# train acc: tensor(0.7059, device='cuda:0')
# dev_acc: tensor(0.4240, device='cuda:0')
# epoch: 198
# train acc: tensor(0.7071, device='cuda:0')
# dev_acc: tensor(0.4234, device='cuda:0')
# epoch: 199
# train acc: tensor(0.7083, device='cuda:0')
# dev_acc: tensor(0.4229, device='cuda:0')

# %%
def predict(net,dataloader):
    net.eval()
    predictions = torch.tensor([]).cuda(gpu)
    with torch.no_grad():
        for i, (x,y) in enumerate(test_loader):
            x,y=x.cuda(gpu),y.cuda(gpu)
            logit = net(x)
            pred = torch.argmax(logit,dim=1)+1
            predictions=torch.cat((predictions,pred))
    return predictions.cpu().numpy()
pred = predict(net,test_loader)
print(pred)
# Out:
# [ 9.  3. 10. ...  6.  6.  8.]

# %%
output = pd.read_csv("sample.csv")
output['Category']=pred.astype('int')
output.head()
output.to_csv("predictions.csv",index=None)

# %%
data = pd.read_csv("drive/MyDrive/SML/training_set.csv",header=None)
