# %%
from google.colab import drive 
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import time

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torch.utils.data import TensorDataset, DataLoader, Dataset
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Reshape the features to (16, 20, 3)
def To3DFeatures(array):
    new_array = []

    for row in array:
        frame_list = []
        one_frame = []
        joint_coordinate = []
        for index, item in enumerate(row):
          joint_coordinate.append(item)
          if index % 3 == 2:
            one_frame.append(joint_coordinate)
            joint_coordinate = []
          if index % 60 == 59:
              frame_list.append(one_frame)
              one_frame = []
        new_array.append(frame_list)
    
    return new_array

#DO substraction to get motion vectors
def ToMotionFeature(array):
    motion_feature = []
    
    for index1, frame_list in enumerate(array):
        frame_motion = []
        for index2, frame in enumerate(frame_list):
            if index2 > 0:
                motion = []
                for index3, joint in enumerate(frame):
                    
                    x_movement = frame_list[index2][index3][0] - frame_list[index2 - 1][index3][0]
                    y_movement = frame_list[index2][index3][1] - frame_list[index2 - 1][index3][1]
                    z_movement = frame_list[index2][index3][2] - frame_list[index2 - 1][index3][2]
                    motion.append([x_movement, y_movement, z_movement])
                frame_motion.append(motion)   
                
                
        motion_feature.append(frame_motion)
    return torch.FloatTensor(motion_feature)

def DataSplit(data, r1 = 5, r2 = 10, split_size = 0.2):
  #input: loaded data,
  #output: train, validation, test set (np array)
  #explanation: remove the first column (id), feature set is the column from 1 - 960, test set is the column 961

  features = [i for i in range(1,961)]
  labels = [961]
  
  x_train = data[features]
  y_train = data[labels]

  x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = split_size, random_state = r1)
  x_validation, x_test, y_validation, y_test = train_test_split(x_test, y_test, test_size = 0.5, random_state = r2)


  return x_train.values, x_validation.values, x_test.values, y_train.values, y_validation.values, y_test.values

# %%
train_path = '/content/drive/MyDrive/Project1-Group 46/train.csv'
test_path = '/content/drive/MyDrive/Project1-Group 46/test.csv'

train_data = pd.read_csv(train_path, header = None)


x_train, x_validation, x_test, y_train, y_validation, y_test = DataSplit(train_data)



x_train = To3DFeatures(x_train)
x_validation = To3DFeatures(x_validation)
x_test = To3DFeatures(x_test)



x_train = torch.FloatTensor(x_train)
x_validation = torch.FloatTensor(x_validation)
x_test = torch.FloatTensor(x_test)
y_train = torch.LongTensor(y_train)
y_validation = torch.LongTensor(y_validation)
y_test = torch.LongTensor(y_test)

y_train = torch.flatten(y_train)
y_validation = torch.flatten(y_validation)
y_test = torch.flatten(y_test)



x_train_motion = ToMotionFeature(x_train)
x_validation_motion = ToMotionFeature(x_validation)
x_test_motion = ToMotionFeature(x_test)



x_train = np.swapaxes(x_train,1,3)
x_validation = np.swapaxes(x_validation,1,3)
x_test = np.swapaxes(x_test,1,3)

x_train_motion = np.swapaxes(x_train_motion,1,3)
x_validation_motion = np.swapaxes(x_validation_motion,1,3)
x_test_motion = np.swapaxes(x_test_motion,1,3)

# %%
class SKEDataset(Dataset):

    def __init__(self, x1_train, x2_train, y_train):

        self.x1_train = x1_train
        self.x2_train = x2_train

        self.y_train = y_train

    def __len__(self):
        return len(self.x1_train)

    def __getitem__(self, index):


        return self.x1_train[index], self.x2_train[index], self.y_train[index]


train_set = SKEDataset(x_train, x_train_motion, y_train)
dev_set = SKEDataset(x_validation, x_validation_motion, y_validation)


train_loader = DataLoader(train_set, batch_size = 64)
dev_loader = DataLoader(dev_set, batch_size = 64)

# %%
class CNN2d_x1(nn.Module):
  def __init__(self):
    super(CNN2d_x1, self).__init__()

    #20 * 16 * 3
    self.conv1 = nn.Sequential(
        nn.Conv2d(in_channels=3, 
                  out_channels=16, 
                  kernel_size=3, 
                  stride = 1,
                  padding = 1
        ),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size = 2,stride = 2)
    )

    #16 * 10 * 8  


  def forward(self, x):
    x = self.conv1(x)

    return x


class CNN2d_x2(nn.Module):
  def __init__(self):
    super(CNN2d_x2, self).__init__()

    # 3 * 20 * 15
    self.conv1 = nn.Sequential(
        nn.Conv2d(in_channels=3, 
                  out_channels=16, 
                  kernel_size=3, 
                  stride = 1,
                  padding = 1
        ),
        nn.ReLU(),
        nn.MaxPool2d(kernel_size = 2,stride = 2)
    )

    #16 * 10 * 7 

  def forward(self, x):
    x = self.conv1(x)

    return x

class Ensemble(nn.Module):
    def __init__(self, modelA, modelB):
        super(Ensemble, self).__init__()
    
        self.modelA = modelA
        self.modelB = modelB
        
        self.fc1 = nn.Linear(16 * 10 * 15, 50)
    
    
        #16 * 10 * 7 
    
    def forward(self, x1, x2):
      x1 = self.modelA(x1)
      x2 = self.modelB(x2)
      
      x = torch.cat((x1,x2), dim = 3)
      x = x.view(-1, 16 * 10 * 15)
      
      x = self.fc1(x)
      
      return F.log_softmax(x, dim=1)

# %%
def train(model, criterion, opti, train_loader, dev_loader, max_eps):
  best_acc = 0
  st = time.time()

  train_correct = []
  dev_correct = []
  train_losses = []
  dev_losses = []
  for ep in range(max_eps):
    trn_corr = 0
    tst_corr = 0
    total_y = 0
    count = 0
    mean_loss = 0

    for b, (x1_train, x2_train, y_train) in enumerate(train_loader):
      b += 1
      y_pred = model(x1_train, x2_train)
      loss = criterion(y_pred, y_train)

      predicted = torch.max(y_pred.data, 1)[1]
      batch_corr = (predicted == y_train).sum()
      trn_corr += batch_corr

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      if b % 30 == 0:
        print(("Iteration {} of epoch {} complete. Loss: {}; Acc =: {}, Time taken (s): {}".format(b, ep, loss.item(), batch_corr/len(y_train), (time.time()-st))))
    

    with torch.no_grad():
      for b,(x1_dev, x2_dev, y_dev) in enumerate(dev_loader):
        y_val = model(x1_dev, x2_dev)
        predicted = torch.max(y_val.data,1)[1]
        tst_corr += (predicted == y_dev).sum()
        total_y += len(predicted)
        count += 1

        mean_loss += criterion(y_val, y_dev)
    
    acc_dev = tst_corr / total_y
    mean_loss = mean_loss / count

    print("Epoch {} complete! Development Accuracy: {}; Development Loss: {}".format(ep, acc_dev, mean_loss))
    if acc_dev > best_acc:
        print("Best development accuracy improved from {} to {}, saving model...".format(best_acc, acc_dev))
        best_acc = acc_dev
        torch.save(model.state_dict(), 'sstcls_{}.dat'.format(ep))

# %%
model_a = CNN2d_x1()
model_b = CNN2d_x2()

ensemble_model = Ensemble(model_a, model_b)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(ensemble_model.parameters(), lr = 0.001)
max_eps = 100
train(ensemble_model, criterion, optimizer, train_loader, dev_loader, max_eps)
# Out:
# Iteration 30 of epoch 0 complete. Loss: 14.889373779296875; Acc =: 0.203125, Time taken (s): 0.7299737930297852
# Iteration 60 of epoch 0 complete. Loss: 13.601811408996582; Acc =: 0.203125, Time taken (s): 1.4300177097320557
# Iteration 90 of epoch 0 complete. Loss: 12.285259246826172; Acc =: 0.265625, Time taken (s): 2.0730926990509033
# Epoch 0 complete! Development Accuracy: 0.2587859332561493; Development Loss: 10.29552173614502
# Best development accuracy improved from 0 to 0.2587859332561493, saving model...
# Iteration 30 of epoch 1 complete. Loss: 5.746011734008789; Acc =: 0.390625, Time taken (s): 3.3570139408111572
# Iteration 60 of epoch 1 complete. Loss: 4.8409528732299805; Acc =: 0.390625, Time taken (s): 3.926466226577759
# Iteration 90 of epoch 1 complete. Loss: 4.587430953979492; Acc =: 0.34375, Time taken (s): 4.502578496932983
# Epoch 1 complete! Development Accuracy: 0.30990415811538696; Development Loss: 7.1704630851745605
# Best development accuracy improved from 0.2587859332561493 to 0.30990415811538696, saving model...
# Iteration 30 of epoch 2 complete. Loss: 2.8655858039855957; Acc =: 0.5, Time taken (s): 5.6998291015625
# Iteration 60 of epoch 2 complete. Loss: 3.5956039428710938; Acc =: 0.421875, Time taken (s): 6.29296875
# Iteration 90 of epoch 2 complete. Loss: 3.6964097023010254; Acc =: 0.34375, Time taken (s): 6.894024610519409
# Epoch 2 complete! Development Accuracy: 0.3343982994556427; Development Loss: 5.816335678100586
# Best development accuracy improved from 0.30990415811538696 to 0.3343982994556427, saving model...
# Iteration 30 of epoch 3 complete. Loss: 1.522268533706665; Acc =: 0.59375, Time taken (s): 8.130772829055786
# Iteration 60 of epoch 3 complete. Loss: 2.6944518089294434; Acc =: 0.5625, Time taken (s): 8.730018138885498
# Iteration 90 of epoch 3 complete. Loss: 2.6898598670959473; Acc =: 0.421875, Time taken (s): 9.308794498443604
# Epoch 3 complete! Development Accuracy: 0.3354632556438446; Development Loss: 6.507765769958496
# Best development accuracy improved from 0.3343982994556427 to 0.3354632556438446, saving model...
# Iteration 30 of epoch 4 complete. Loss: 1.9259284734725952; Acc =: 0.53125, Time taken (s): 10.549397706985474
# Iteration 60 of epoch 4 complete. Loss: 2.04150128364563; Acc =: 0.515625, Time taken (s): 11.130210399627686
# Iteration 90 of epoch 4 complete. Loss: 1.5423729419708252; Acc =: 0.65625, Time taken (s): 11.669028520584106
# Epoch 4 complete! Development Accuracy: 0.36528220772743225; Development Loss: 5.4459452629089355
# Iteration 30 of epoch 94 complete. Loss: 0.037176020443439484; Acc =: 0.984375, Time taken (s): 275.68851137161255
# Iteration 60 of epoch 94 complete. Loss: 0.09371555596590042; Acc =: 0.984375, Time taken (s): 276.4971089363098
# Iteration 90 of epoch 94 complete. Loss: 0.15872801840305328; Acc =: 0.953125, Time taken (s): 277.3544316291809
# Epoch 94 complete! Development Accuracy: 0.41853034496307373; Development Loss: 21.4547061920166
# Iteration 30 of epoch 95 complete. Loss: 0.021540310233831406; Acc =: 1.0, Time taken (s): 279.01594614982605
# Iteration 60 of epoch 95 complete. Loss: 0.17303942143917084; Acc =: 0.953125, Time taken (s): 279.8287744522095
# Iteration 90 of epoch 95 complete. Loss: 0.21756738424301147; Acc =: 0.9375, Time taken (s): 280.6709351539612
# Epoch 95 complete! Development Accuracy: 0.4206602871417999; Development Loss: 21.986562728881836
# Iteration 30 of epoch 96 complete. Loss: 0.09892881661653519; Acc =: 0.96875, Time taken (s): 282.32218384742737
# Iteration 60 of epoch 96 complete. Loss: 0.4118002951145172; Acc =: 0.9375, Time taken (s): 283.14185976982117
# Iteration 90 of epoch 96 complete. Loss: 0.10137292742729187; Acc =: 0.953125, Time taken (s): 283.95128059387207
# Epoch 96 complete! Development Accuracy: 0.42172524333000183; Development Loss: 22.09162139892578
# Iteration 30 of epoch 97 complete. Loss: 0.3511573076248169; Acc =: 0.953125, Time taken (s): 285.7103624343872
# Iteration 60 of epoch 97 complete. Loss: 0.5911936163902283; Acc =: 0.875, Time taken (s): 286.5336015224457
# Iteration 90 of epoch 97 complete. Loss: 0.2593238055706024; Acc =: 0.953125, Time taken (s): 287.4228901863098
# Epoch 97 complete! Development Accuracy: 0.4004259705543518; Development Loss: 22.742517471313477
# Iteration 30 of epoch 98 complete. Loss: 0.05649916082620621; Acc =: 0.96875, Time taken (s): 289.1010763645172
# Iteration 60 of epoch 98 complete. Loss: 0.4474816620349884; Acc =: 0.875, Time taken (s): 289.91412353515625
# Iteration 90 of epoch 98 complete. Loss: 0.779772162437439; Acc =: 0.84375, Time taken (s): 290.72101354599
# Epoch 98 complete! Development Accuracy: 0.402555912733078; Development Loss: 23.46695899963379
# Iteration 30 of epoch 99 complete. Loss: 1.2280900478363037; Acc =: 0.90625, Time taken (s): 292.3629558086395
# Iteration 60 of epoch 99 complete. Loss: 0.24436873197555542; Acc =: 0.953125, Time taken (s): 293.2329261302948
# Iteration 90 of epoch 99 complete. Loss: 0.2088635414838791; Acc =: 0.9375, Time taken (s): 294.06768131256104
# Epoch 99 complete! Development Accuracy: 0.4142704904079437; Development Loss: 25.7526912689209

# %%
pre_model_a = CNN2d_x1()
pre_model_b = CNN2d_x2()

predict_model = Ensemble(pre_model_a, pre_model_b)
predict_model.load_state_dict(torch.load('sstcls_47.dat'))

with torch.no_grad():
  y_eval = predict_model.forward(x_test, x_test_motion)
  loss = criterion(y_eval, y_test)
  prediction = torch.max(y_eval.data,1)[1]

# %% [markdown]
# Accuracy for development set

# %%
accuracy_score(y_test, prediction)
# Out:
# 0.40894568690095845
